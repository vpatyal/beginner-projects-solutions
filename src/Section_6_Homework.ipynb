# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
df_movies = pd.read_csv("C:\\Users\\vpatyal\\Dropbox\\learn\\PythonPrograms\\jupyterNBcode\\data\\P4-Section6-Homework-Dataset.csv", encoding='latin1')

# %%
df_movies.columns = ['DayofWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossMillions', 'BudgetMillions', 'GrossMillions',
       'IMDbRating', 'MovieLensRating', 'OverseasMillions', 'OverseasPercentage',
       'ProfitMillions', 'ProfitPercentage', 'Runtime', 'USMillions',
       'GrossUSPercentage']

# %%
len(df_movies)
# Out:
# 608

# %%
df_movies['Genre'] = df_movies['Genre'].astype('category')
df_movies['Studio'] = df_movies['Studio'].astype('category')

# %%
df_movies2 = df_movies[df_movies['Genre'].isin(['action','comedy','adventure','animation','drama'])]

# %%
df_movies3 = df_movies2[df_movies2['Studio'].isin(['Fox','WB','Buena Vista Studios','Paramount Pictures','Sony', 'Universal'])].reset_index()

# %%
(df_movies3.Studio.unique())
# Out:
# [Buena Vista Studios, Sony, Universal, WB, Paramount Pictures, Fox]
# Categories (6, object): [Buena Vista Studios, Sony, Universal, WB, Paramount Pictures, Fox]

# %%
df_movies3 = df_movies3.drop('index', axis=1)

# %%
len(df_movies3)
# Out:
# 423

# %%
sns.set(style = 'darkgrid', palette='muted', color_codes=True)

# %%
ax = sns.boxplot(data = df_movies3, x='Genre', y='GrossUSPercentage', orient='v', color='lightgrey', showfliers=False)

plt.setp(ax.artists, alpha=0.5)

sns.stripplot(data = df_movies3, x='Genre', y='GrossUSPercentage', jitter=True, size=6, linewidth=0, hue='Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross % by Genre', fontsize=30)
ax.set_xlabel('Genre', fontsize=20)
ax.set_ylabel('Gross % US', fontsize=20)

ax.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
df_movies3
# Out:
#      DayofWeek                     Director      Genre  \
# 0       Friday                    Brad Bird     action
# 1       Friday                  Scott Waugh     action
# 2       Friday      Phil Lord, Chris Miller     comedy
# 3       Friday              Roland Emmerich     action
# 4       Friday                   David Ayer     action
# 5     Thursday                 Rob Marshall  adventure
# 6       Friday              Daniel Espinosa     action
# 7       Friday                   Gary Shore     action
# 8       Friday                  Eric Brevig  animation
# 9       Friday                  Ryan Murphy      drama
# 10      Friday              Paul Greengrass      drama
# 11      Friday               Hayao Miyazaki  animation
# 12      Friday           Jaume Collet-Serra     action
# 13      Friday           Jonathan Liebesman     action
# 14      Friday        Christopher McQuarrie     action
# 15      Friday                 Dennis Dugan     comedy
# ...

# %%
df_movies
# Out:
#      DayofWeek                                           Director      Genre  \
# 0       Friday                                          Brad Bird     action
# 1       Friday                                        Scott Waugh     action
# 2       Friday                                     Patrick Hughes     action
# 3       Friday                            Phil Lord, Chris Miller     comedy
# 4       Friday                                    Roland Emmerich     action
# 5       Friday                                         David Ayer     action
# 6     Thursday                                       Rob Marshall  adventure
# 7       Friday                                    Daniel Espinosa     action
# 8       Friday                                         Gary Shore     action
# 9       Friday                        Henry Joost, Ariel Schulman     horror
# 10      Friday                                        Eric Brevig  animation
# ...
